# %%
import torch
import pandas as pd
import numpy as np
import json, re

# Torch, Sklearn imports
from sklearn.model_selection import train_test_split
import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
print(torch.__version__)

## NLP libs
from nltk import download
import gensim
from nltk.corpus import stopwords
download('stopwords')
# Out:
# 0.4.1
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/rsilvei/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Importing SNIPS intent dataset

# %%
dataset = pd.DataFrame(columns = ['phrase', 'intent'])

# %%
for intent in ['AddToPlaylist', 'BookRestaurant', 'GetWeather', 'PlayMusic', 'RateBook', 'SearchCreativeWork',
               'SearchScreeningEvent']:
    with open("./2017-06-custom-intent-engines/" + intent + "/train_" + intent + ".json",
              encoding='cp1251') as data_file:
        data = json.load(data_file)
    print("Intent: {}, Length: {}".format(intent,len(data[intent])))
    texts = []
    for i in range(len(data[intent])):
        text = ''
        for j in range(len(data[intent][i]['data'])):
            text += data[intent][i]['data'][j]['text']
        dataset = dataset.append({'phrase': text, 'intent': intent}, ignore_index=True)
# Out:
# Intent: AddToPlaylist, Length: 300
# Intent: BookRestaurant, Length: 300
# Intent: GetWeather, Length: 300
# Intent: PlayMusic, Length: 300
# Intent: RateBook, Length: 300
# Intent: SearchCreativeWork, Length: 300
# Intent: SearchScreeningEvent, Length: 300

# %%
dataset.intent.unique()
# Out:
# array(['AddToPlaylist', 'BookRestaurant', 'GetWeather', 'PlayMusic',
#        'RateBook', 'SearchCreativeWork', 'SearchScreeningEvent'],
#       dtype=object)

# %%
def transformText(text, do_stop=False, do_stem=False):
    stops = set(stopwords.words("english"))
    # Convert text to lower
    text = text.lower()
    
    # Cleaning input
    text = text.replace("'s","")
    text = text.replace("’s","")
    text = text.replace("?","")
    text = text.replace("-","")
    
    # Removing non ASCII chars    
    text = re.sub(r'[^\x00-\x7f]',r' ',text)
    # Strip multiple whitespaces
    text = gensim.corpora.textcorpus.strip_multiple_whitespaces(text)
    # Removing all the stopwords
    if (do_stop==True):
        filtered_words = [word for word in text.split() if word not in stops]
    else:
        filtered_words = [word for word in text.split()]
    # Preprocessed text after stop words removal
    text = " ".join(filtered_words)
    # Remove the punctuation
    text = gensim.parsing.preprocessing.strip_punctuation2(text)
    # Strip multiple whitespaces
    text = gensim.corpora.textcorpus.strip_multiple_whitespaces(text)
    if (do_stem==True):
        # Stemming
        text = gensim.parsing.preprocessing.stem_text(text)
    return text

def strip_punctuation(s):
    return ''.join(c for c in s if c not in PUNCT)

## Lemmatization function based on Spacy Library
def lemmatizer_spacy(text):        
    sent = []
    doc = spacy_en(text)
    for word in doc:
        if word.lemma_ == "-PRON-":
            sent.append(word.text)
        else:
            sent.append(word.lemma_)
    return " ".join(sent)

def strip_punctuation(s):
    return ''.join(c for c in s if c not in punctuation)

# %%
dataset['preproc_text'] = dataset['phrase'].apply(lambda x: transformText(x))

# %%
dataset
# Out:
#                                                  phrase                intent  \
# 0     add Stani, stani Ibar vodo songs in my playlis...         AddToPlaylist
# 1                   add this album to my Blues playlist         AddToPlaylist
# 2              Add the tune to the Rage Radio playlist.         AddToPlaylist
# 3          Add WC Handy to my Sax and the City playlist         AddToPlaylist
# 4                 Add BSlade to women of k-pop playlist         AddToPlaylist
# 5       add the current tune to my Rock Gaming playlist         AddToPlaylist
# 6      add villotta to The MetalSucks Playlist playlist         AddToPlaylist
# 7            Add Bronislau Kaper to the drive playlist.         AddToPlaylist
# 8     add the artist joseph meyer to my mad cool fes...         AddToPlaylist
# 9      Add the avispa track to my Bass Gaming playlist.         AddToPlaylist
# 10    add bob klose to la mejor mГєsica para tus fie...         AddToPlaylist
# 11    Add como un tatuaje to my hits of the 70s play...         AddToPlaylist
# 12           Add this tune to the sylvia plath playlist         AddToPlaylist
# 13            add an album in Guitar Hero Live Playlist         AddToPlaylist
# 14        add Chris de Burgh in my playlist melancholia         AddToPlaylist
# 15          Add John Tesh to my salsa classics playlist         AddToPlaylist
# 16    add the current tune to my Six string peaceful...         AddToPlaylist
# 17                Add the track to my workout playlist.         AddToPlaylist
# 18            Add the album to my Heavy Gamer playlist.         AddToPlaylist
# 19     add an album in my playlist In The Name Of Blues         AddToPlaylist
# 20              add bang a drum to my cleaning playlist         AddToPlaylist
# 21        Add the track to the bandas sonoras playlist.         AddToPlaylist
# 22       Add the track to my romantic evening playlist.         AddToPlaylist
# 23    Add decade in the sun best of stereophonics to...         AddToPlaylist
# 24    I'd like to put qriii onto songs to sing in th...         AddToPlaylist
# 25               add Dunja, du to my ejercicio playlist         AddToPlaylist
# 26    I want to send music to ann's lists from SIR J...         AddToPlaylist
# 27    Please put maimi yajima's song onto OperaciГіn...         AddToPlaylist
# 28    add artist in my\n Top 100 Rock Tracks on Spotify         AddToPlaylist
# 29    Add the artist Jurij Szewczuk to tisha's soul ...         AddToPlaylist
# ...                                                 ...                   ...
# 2070          Find movie schedules for Bow Tie Cinemas.  SearchScreeningEvent
# 2071  Is it possible to see The Day of the Jackal at...  SearchScreeningEvent
# 2072  What times will The Garden of sinners Film 1 в...  SearchScreeningEvent
# 2073  What movies are playing at the closest movie t...  SearchScreeningEvent
# 2074  Is Outlaw of Gor showing at thenearest movie h...  SearchScreeningEvent
# 2075   Kingsman: The Secret Service at my movie theatre  SearchScreeningEvent
# 2076  What is the movie schedule for the Pacific The...  SearchScreeningEvent
# 2077  Find the schedule for Project Shadowchaser II ...  SearchScreeningEvent
# 2078  Show me a theater close by with 2 p.m. or late...  SearchScreeningEvent
# 2079                Find the schedule for The Wild Eye.  SearchScreeningEvent
# 2080         Please look for The Pagans at movie house.  SearchScreeningEvent
# 2081  When will The Flower and the Angry Waves be sh...  SearchScreeningEvent
# 2082  I want to see The Band of Honest Men at the ne...  SearchScreeningEvent
# 2083        What is playing  at the closest movie house  SearchScreeningEvent
# 2084             show me the movies playing around here  SearchScreeningEvent
# 2085  When is Four Days in November playing at the m...  SearchScreeningEvent
# 2086                Can I get the newest movie schedule  SearchScreeningEvent
# 2087  what's the nearest movie theatre showing Concu...  SearchScreeningEvent
# 2088      What movies are playing at the closest cinema  SearchScreeningEvent
# 2089  I want to see showings for The Voice of Merril...  SearchScreeningEvent
# 2090  I want to see a list of the closest cinema's m...  SearchScreeningEvent
# 2091  What Are the showings for The Natural History ...  SearchScreeningEvent
# 2092  Give me the schedule for Public Stenographer a...  SearchScreeningEvent
# 2093  Is it possible to see Tube at the closest movi...  SearchScreeningEvent
# 2094  I want to see Wenn Lucy springt now at a movie...  SearchScreeningEvent
# 2095  Is Across the Line playing at the closest movi...  SearchScreeningEvent
# 2096  Which animated movies are playing in the neigh...  SearchScreeningEvent
# 2097        Where is They Always Return at Dawn playing  SearchScreeningEvent
# 2098     What is the movie schedule in the neighborhood  SearchScreeningEvent
# 2099  Tell me when Howling II: Your Sister Is a Were...  SearchScreeningEvent
#
#                                            preproc_text
# 0     add stani stani ibar vodo songs in my playlist...
# 1                   add this album to my blues playlist
# 2              add the tune to the rage radio playlist
# 3          add wc handy to my sax and the city playlist
# 4                  add bslade to women of kpop playlist
# 5       add the current tune to my rock gaming playlist
# 6      add villotta to the metalsucks playlist playlist
# 7            add bronislau kaper to the drive playlist
# 8     add the artist joseph meyer to my mad cool fes...
# 9      add the avispa track to my bass gaming playlist
# 10    add bob klose to la mejor m sica para tus fiestas
# 11    add como un tatuaje to my hits of the 70s play...
# 12           add this tune to the sylvia plath playlist
# 13            add an album in guitar hero live playlist
# 14        add chris de burgh in my playlist melancholia
# 15          add john tesh to my salsa classics playlist
# 16    add the current tune to my six string peaceful...
# 17                add the track to my workout playlist
# 18            add the album to my heavy gamer playlist
# 19     add an album in my playlist in the name of blues
# 20              add bang a drum to my cleaning playlist
# 21        add the track to the bandas sonoras playlist
# 22       add the track to my romantic evening playlist
# 23    add decade in the sun best of stereophonics to...
# 24    i d like to put qriii onto songs to sing in th...
# 25                add dunja du to my ejercicio playlist
# 26    i want to send music to ann lists from sir joh...
# 27    please put maimi yajima song onto operaci n bi...
# 28      add artist in my top 100 rock tracks on spotify
# 29    add the artist jurij szewczuk to tisha soul re...
# ...                                                 ...
# 2070          find movie schedules for bow tie cinemas
# 2071  is it possible to see the day of the jackal at...
# 2072  what times will the garden of sinners film 1 t...
# 2073  what movies are playing at the closest movie t...
# 2074  is outlaw of gor showing at thenearest movie h...
# 2075    kingsman the secret service at my movie theatre
# 2076  what is the movie schedule for the pacific the...
# 2077  find the schedule for project shadowchaser ii ...
# 2078  show me a theater close by with 2 p m or later...
# 2079                find the schedule for the wild eye
# 2080         please look for the pagans at movie house
# 2081  when will the flower and the angry waves be sh...
# 2082  i want to see the band of honest men at the ne...
# 2083         what is playing at the closest movie house
# 2084             show me the movies playing around here
# 2085  when is four days in november playing at the m...
# 2086                can i get the newest movie schedule
# 2087  what the nearest movie theatre showing concuss...
# 2088      what movies are playing at the closest cinema
# 2089  i want to see showings for the voice of merril...
# 2090  i want to see a list of the closest cinema movies
# 2091  what are the showings for the natural history ...
# 2092  give me the schedule for public stenographer a...
# 2093  is it possible to see tube at the closest movi...
# 2094  i want to see wenn lucy springt now at a movie...
# 2095  is across the line playing at the closest movi...
# 2096  which animated movies are playing in the neigh...
# 2097        where is they always return at dawn playing
# 2098     what is the movie schedule in the neighborhood
# 2099  tell me when howling ii your sister is a werew...
#
# [2100 rows x 3 columns]
